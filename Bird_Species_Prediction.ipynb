# %% [markdown]
# <a href="https://colab.research.google.com/github/Arpan-000/Bird_species_Prediction/blob/main/Bird_Species_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bird Species Prediction

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict species of the bird. We will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. We will be using keras for this project.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# '1 oct class.gdoc'
# '24th sept.gdoc'
# '2d shapes.gdoc'
# '3d shapes.gdoc'
# 'a43ce034-a971-4dd4-b432-c33965adb5b8 (1).xlsx'
#  a43ce034-a971-4dd4-b432-c33965adb5b8-2.xlsx
#  a43ce034-a971-4dd4-b432-c33965adb5b8.xlsx
# 'ACS(4 people).gdoc'
#  ACS.gdoc
# 'ACS printout.gdoc'
# 'Add a heading-page-001.jpg'
# 'APPLIED PHYSICS.pdf'
#  arpan.pdf
# 'Arpan Resume(final).pdf'
# 'Arpan'\''s Resume (1).pdf'
# "Arpan's Resume.pdf"
#  article_careers360_20211121124935.gdoc
#  article_careers360_20211121124935.pdf
# 'A Textbook of Engineering Physics by M N Avadhanulu [Avadhanulu, M N] (z-lib.org).pdf'
# 'Bird Speciees Dataset'
# 'CN Mid1 important Question bank_copy.pdf'
# 'Colab Notebooks'
# 'Collab Code-8'
# 'Consent Form.docx'
# 'Copy of Hyderabad - Hackerank Registrations - FY24 CSG.xlsx'
# 'Cover Letter.gdoc'
#  cse
#  CSE-B.MOV
#  CV
#  Data
# 'Document from Arpan tiwari (1).pdf'
# 'Document from Arpan tiwari.pdf'
# 'Event Feedback (1).gform'
# 'Event Feedback (2).gform'
# 'Event Feedback.gform'
#  Event.gsite
# 'Express letter.gdoc'
# 'Express Quotation.gdoc'
# 'Final draft.gdoc'
# 'Flipkart GRID Document - Arsh Goyal.gdoc'
# 'FOS_2022 (1).zip'
#  IMG_20220716_134356.jpg
#  IMG_20220716_134410.jpg
#  IMG_20220716_134414.jpg
# 'ITC jeedipally-dec-23-2.xlsx'
# 'ITC october-23.gsheet'
#  kahna2.gdoc
#  kahna.gdoc
# "mahesh'scode.exe"
#  MaheshVardhan_CV.gdoc
# 'phy assignment.pdf'
# 'pics print record and observation.gdoc'
# 'pics print record and observation.pdf'
#  Pitch.gdoc
# 'Portfolio (1).gsite'
# 'Portfolio (2).gsite'
#  Portfolio.gsite
# 'PRINT DRAFT.gdoc'
# 'print .gdoc'
# 'Research Statement: Unraveling the Mystery of Fake News.gdoc'
#  resume
# 'RESUME(IIITH).pdf'
# 'SALARYNAMI (1).xlsx'
# 'SALARYNAMI (2).xlsx'
#  SALARYNAMI.xlsx
# 'Scan_20211220 (2).jpg'
# 'Scan_20211220 (2)-min.pdf'
# 'Scan_20211220 (3).jpg'
# 'Scan_20211220 (3)-min.pdf'
#  Scan_20211220.jpg
#  Scan_20211220-min.pdf
# 'Scan_20230228 (2).pdf'
# 'Scan_20230228 (3).pdf'
# 'Scan_20230228 (4).pdf'
# 'Scan_20230228 (5).pdf'
#  Scan_20230228.pdf
# 'Scan_20230802 (4).gdoc'
# 'Scan_20230802 (4).pdf'
#  Screenshot_2023-12-14-05-37-46-57_944a2809ea1b4cda6ef12d1db9048ed3.jpg
#  sor.cpp
# 'ssc.jpg (1×1)'
#  SUM_410603359288_436003836372_20231122.pdf
# 'THE GREAT MATHMATICAL DUEL.pptx'
# 'Topics of 17th sept.gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet.gsheet'
# 'VE-66-I B.Tech. II Semester (R18) Regular.xlsx'
# 'WhatsApp Image 2023-06-04 at 5.38.15 PM.xlsx'
# 'WhatsApp Image 2023-12-14 at 05.38.03.jpeg'
# 'wtn-rfru-tjh - Nov 15, 2021.gjam'

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here you can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that we will work on.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting path and creating empty list
dir = "/content/drive/My Drive/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 37, 16)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPoolin  (None, 18, 18, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338038 (1.29 MB)
# Trainable params: 338038 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 7s 375ms/step - loss: 1.7807 - accuracy: 0.2317 - val_loss: 1.7176 - val_accuracy: 0.3154
# Epoch 2/50
# 5/5 [==============================] - 1s 113ms/step - loss: 1.7034 - accuracy: 0.2722 - val_loss: 1.7002 - val_accuracy: 0.2846
# Epoch 3/50
# 5/5 [==============================] - 1s 120ms/step - loss: 1.6640 - accuracy: 0.3185 - val_loss: 1.6196 - val_accuracy: 0.3846
# Epoch 4/50
# 5/5 [==============================] - 1s 120ms/step - loss: 1.5759 - accuracy: 0.4305 - val_loss: 1.5956 - val_accuracy: 0.3000
# Epoch 5/50
# 5/5 [==============================] - 1s 118ms/step - loss: 1.4857 - accuracy: 0.4749 - val_loss: 1.5088 - val_accuracy: 0.3308
# Epoch 6/50
# 5/5 [==============================] - 1s 105ms/step - loss: 1.4035 - accuracy: 0.4363 - val_loss: 1.4584 - val_accuracy: 0.5000
# Epoch 7/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.3469 - accuracy: 0.6197 - val_loss: 1.3651 - val_accuracy: 0.5538
# Epoch 8/50
# 5/5 [==============================] - 0s 84ms/step - loss: 1.3118 - accuracy: 0.5367 - val_loss: 1.3166 - val_accuracy: 0.4538
# Epoch 9/50
# 5/5 [==============================] - 0s 78ms/step - loss: 1.2684 - accuracy: 0.5772 - val_loss: 1.4087 - val_accuracy: 0.4615
# Epoch 10/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.1884 - accuracy: 0.6622 - val_loss: 1.1525 - val_accuracy: 0.6538
# Epoch 11/50
# 5/5 [==============================] - 0s 82ms/step - loss: 1.2115 - accuracy: 0.5830 - val_loss: 1.1255 - val_accuracy: 0.5923
# Epoch 12/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.0401 - accuracy: 0.6911 - val_loss: 1.2741 - val_accuracy: 0.5308
# Epoch 13/50
# 5/5 [==============================] - 0s 97ms/step - loss: 1.0818 - accuracy: 0.6236 - val_loss: 1.0150 - val_accuracy: 0.6692
# Epoch 14/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.9558 - accuracy: 0.6776 - val_loss: 1.0432 - val_accuracy: 0.6385
# Epoch 15/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.9287 - accuracy: 0.6680 - val_loss: 1.0064 - val_accuracy: 0.6615
# Epoch 16/50
# 5/5 [==============================] - 0s 98ms/step - loss: 0.8359 - accuracy: 0.7278 - val_loss: 0.9592 - val_accuracy: 0.7000
# Epoch 17/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.7717 - accuracy: 0.7780 - val_loss: 0.8598 - val_accuracy: 0.7615
# Epoch 18/50
# 5/5 [==============================] - 0s 84ms/step - loss: 0.7128 - accuracy: 0.8012 - val_loss: 0.7949 - val_accuracy: 0.7231
# Epoch 19/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.6421 - accuracy: 0.8050 - val_loss: 0.7986 - val_accuracy: 0.7385
# Epoch 20/50
# 5/5 [==============================] - 0s 96ms/step - loss: 0.6416 - accuracy: 0.7761 - val_loss: 0.8367 - val_accuracy: 0.6769
# Epoch 21/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.6355 - accuracy: 0.7838 - val_loss: 0.7398 - val_accuracy: 0.7231
# Epoch 22/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.5743 - accuracy: 0.8147 - val_loss: 0.6524 - val_accuracy: 0.7923
# Epoch 23/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.4914 - accuracy: 0.8784 - val_loss: 0.7008 - val_accuracy: 0.7615
# Epoch 24/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.4745 - accuracy: 0.8649 - val_loss: 0.6396 - val_accuracy: 0.7692
# Epoch 25/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4410 - accuracy: 0.8649 - val_loss: 0.6191 - val_accuracy: 0.7923
# Epoch 26/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.3958 - accuracy: 0.8687 - val_loss: 0.5819 - val_accuracy: 0.7692
# Epoch 27/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.3739 - accuracy: 0.8900 - val_loss: 0.6742 - val_accuracy: 0.7846
# Epoch 28/50
# 5/5 [==============================] - 0s 83ms/step - loss: 0.3742 - accuracy: 0.8919 - val_loss: 0.6340 - val_accuracy: 0.7692
# Epoch 29/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.3547 - accuracy: 0.8977 - val_loss: 0.5412 - val_accuracy: 0.8308
# Epoch 30/50
# 5/5 [==============================] - 0s 82ms/step - loss: 0.3067 - accuracy: 0.9015 - val_loss: 0.6118 - val_accuracy: 0.7846
# Epoch 31/50
# 5/5 [==============================] - 0s 101ms/step - loss: 0.3445 - accuracy: 0.8919 - val_loss: 0.5558 - val_accuracy: 0.8154
# Epoch 32/50
# 5/5 [==============================] - 1s 118ms/step - loss: 0.3059 - accuracy: 0.9054 - val_loss: 0.5424 - val_accuracy: 0.8308
# Epoch 33/50
# 5/5 [==============================] - 1s 119ms/step - loss: 0.2737 - accuracy: 0.9228 - val_loss: 0.7095 - val_accuracy: 0.7538
# Epoch 34/50
# 5/5 [==============================] - 1s 116ms/step - loss: 0.2464 - accuracy: 0.9344 - val_loss: 0.5032 - val_accuracy: 0.8308
# Epoch 35/50
# 5/5 [==============================] - 1s 122ms/step - loss: 0.2299 - accuracy: 0.9363 - val_loss: 0.5446 - val_accuracy: 0.8000
# Epoch 36/50
# 5/5 [==============================] - 1s 118ms/step - loss: 0.1815 - accuracy: 0.9614 - val_loss: 0.6206 - val_accuracy: 0.7846
# Epoch 37/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.2404 - accuracy: 0.9363 - val_loss: 0.4659 - val_accuracy: 0.8231
# Epoch 38/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.2195 - accuracy: 0.9286 - val_loss: 0.7158 - val_accuracy: 0.7846
# Epoch 39/50
# 5/5 [==============================] - 1s 190ms/step - loss: 0.3104 - accuracy: 0.8996 - val_loss: 0.6042 - val_accuracy: 0.7462
# Epoch 40/50
# 5/5 [==============================] - 1s 181ms/step - loss: 0.2680 - accuracy: 0.8996 - val_loss: 0.5481 - val_accuracy: 0.8308
# Epoch 41/50
# 5/5 [==============================] - 1s 125ms/step - loss: 0.2564 - accuracy: 0.9131 - val_loss: 0.5264 - val_accuracy: 0.8077
# Epoch 42/50
# 5/5 [==============================] - 1s 115ms/step - loss: 0.1582 - accuracy: 0.9653 - val_loss: 0.5120 - val_accuracy: 0.7923
# Epoch 43/50
# 5/5 [==============================] - 1s 137ms/step - loss: 0.1357 - accuracy: 0.9749 - val_loss: 0.4541 - val_accuracy: 0.8385
# Epoch 44/50
# 5/5 [==============================] - 1s 161ms/step - loss: 0.1186 - accuracy: 0.9807 - val_loss: 0.5180 - val_accuracy: 0.8231
# Epoch 45/50
# 5/5 [==============================] - 0s 105ms/step - loss: 0.1291 - accuracy: 0.9730 - val_loss: 0.5118 - val_accuracy: 0.8308
# Epoch 46/50
# 5/5 [==============================] - 1s 131ms/step - loss: 0.1361 - accuracy: 0.9788 - val_loss: 0.4774 - val_accuracy: 0.8077
# Epoch 47/50
# 5/5 [==============================] - 1s 163ms/step - loss: 0.1403 - accuracy: 0.9633 - val_loss: 0.4497 - val_accuracy: 0.8385
# Epoch 48/50
# 5/5 [==============================] - 1s 179ms/step - loss: 0.1026 - accuracy: 0.9865 - val_loss: 0.6269 - val_accuracy: 0.8154
# Epoch 49/50
# 5/5 [==============================] - 1s 126ms/step - loss: 0.1039 - accuracy: 0.9807 - val_loss: 0.4306 - val_accuracy: 0.8615
# Epoch 50/50
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0913 - accuracy: 0.9826 - val_loss: 0.4339 - val_accuracy: 0.8308

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 29ms/step - loss: 0.6011 - accuracy: 0.8160
# Test Accuracy: 81.59509301185608

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 11ms/step

# %% [markdown]
# Here we are storing prediction on test data.

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  AMERICAN GOLDFINCH
# Predicted :  AMERICAN GOLDFINCH
